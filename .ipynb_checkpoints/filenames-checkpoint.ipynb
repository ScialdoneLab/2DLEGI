# %%
import pickle
import os
import glob

# %%
subfolders=[x[0] for x in os.walk('./ISD/') if x[0] !='./ISD/']

# %%
subfolders
# Out:
# ['./ISD/set3_Results_D1000.0_l1.0',
#  './ISD/set4_Results_D10.0_l1.0',
#  './ISD/set6_Results_D1000.0_l1.0',
#  './ISD/set9_Results_D10.0_l1.0',
#  './ISD/set9_Results_D1000.0_l1.0',
#  './ISD/set7_Results_D10.0_l1.0',
#  './ISD/set8_Results_D1000.0_l1.0',
#  './ISD/set1_Results_D10.0_l1.0',
#  './ISD/set2_Results_D1000.0_l1.0',
#  './ISD/set7_Results_D1000.0_l1.0',
#  './ISD/set2_Results_D10.0_l1.0',
#  './ISD/set10_Results_D1000.0_l1.0',
#  './ISD/set3_Results_D10.0_l1.0',
#  './ISD/set4_Results_D1000.0_l1.0',
#  './ISD/set1_Results_D1000.0_l1.0',
#  './ISD/set10_Results_D10.0_l1.0',
#  './ISD/set6_Results_D10.0_l1.0',
#  './ISD/set5_Results_D10.0_l1.0',
#  './ISD/set8_Results_D10.0_l1.0',
#  './ISD/set5_Results_D1000.0_l1.0']

# %%
for sub in subfolders:
    subfiles=glob.glob(sub+"/*.ISD")
    for f in subfiles:
        filehandler = open(f, 'rb')
        res_matrices = pickle.load(filehandler)
        print(len(res_matrices))
#         res_matrices = res_matrices[:-1]
        
#         newf=f.replace('LIS','ISD')
#         newfilehandler = open(newf, 'wb') 
#         pickle.dump(res_matrices, newfilehandler)
        
#         os.remove(f)
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# ...
